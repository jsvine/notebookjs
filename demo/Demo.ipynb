# %%
def hello(name="World"):
    print("Hello " + name)

# %%
hello()
# Out:
# Hello World

# %% [markdown]
# # A markdown header
# A little inline LaTeX: $\mathbb{N} \subset \mathbb{R}, \mathbb{R} \subset \mathbb{Z} \Rightarrow \mathbb{N} \subset \mathbb{Z}$
